# %% [markdown]
# ![imagen](./img/python.jpg)

# %% [markdown]
# # Python Colecciones
#
# Las colecciones son una manera de agrupar varios elementos. En otros notebooks vimos cómo funcionan las listas, que es la colección más usada, pero se trata solo de la punta del iceberg. Con Python tenemos varias maneras de almacenar conjuntos de datos, dependiendo del tipo de dato, finalidad, tipo de acceso y rendimiento.
#
# 1. [Listas](#1.-Listas)
# 2. [Tuplas](#2.-Tuplas)
# 3. [Diccionarios](#3.-Diccionarios)
# 4. [Sets](#4.-Sets)
# 5. [Conversiones entre colecciones](#5.-Conversiones-entre-colecciones)
# 6. [Comprensión de listas](#6.-Comprensión-de-listas)
# 7. [Resumen](#7.-Resumen)

# %% [markdown]
# ## 1. Listas
#
# En numpy una lista es un **vector** y una lista de listas es una **matriz**.
#
# En pandas una lista es una **serie** y una lista de listas es un **dataframe**.
#
# Una lista con mas de 2 dimensiones es un **extensor**.
#
# Ya conocemos bastante las listas. Veamos un repaso de lo que podemos hacer con ellas, así como algunas funcionalidades nuevas
#
# Las colecciones más usadas son las listas y los diccionarios.
#
# - listas[]: son ordenadas (se ha de acceder por posición), mutable, puede haber elementos repetidos
# - tuplas(): no son mutables, son ordenadas y permiten elementos repetidos.
# - sets{}: son mutables, son ordenadas pero no permiten elementos repetidos.
# - diccionarios{"clave":"valor"}: no son ordenados porque necesitan un sistema por (clave, valor), no buscamos por su posición, sino por su clave, dentro de la parte valor puede haber una lista, una tupla o un set, son mutables y puede haber valores repetidos, pero no claves.
#
# Se puede hacer transformaciones entre las colecciones.
#     - Lista a tupla y viceversa: se puede
#     - lista a set: se puede, quita los repetidos.
#     - set a lista: se puede.
#     - diccionario a tupla: se puede, es menos problemático.
#     - diccionario a lista: se puede, es menos problemático.
#
# Todas las colecciones pueden albergar diferentes tipos de datos.

# %%
# Listas de números, strings, booleanos, con elementos repetidos, listas anidadas...
nums = [6, 2, 8, 3, 4, 5, 5]
months = ["Enero", "Febrero", "Marzo"]
mix = [5, 7, "Abril", True, None, ["Blanco", "Negro"]]

# Longitud de la lista
print(len(nums))

# Indexación
print(months[1])
print(months[len(months)-1]) 
print(months[-1])
# Out:
# 7
# Febrero
# Marzo
# Marzo

# %% [markdown]
# ### Acceso
# Entre corchetes introducimos el indice del elemento al que queremos acceder

# %%
print(months[0])
print(months[-1])
# Out:
# Enero
# Marzo

# %% [markdown]
# Si planteamos el problema al revés. Tenemos los valores de la lista y lo que queremos es obtener el índice de esos valores dentro de la lista

# %%
months.index("Marzo")
# Out:
# 2

# %% [markdown]
# **Slicing**: usamos slicing para acceder a varios elementos seguidos de la lista

# %%
degrees = [22, 34, 15, 26, 18, 22]

print(degrees[2:4])
print(degrees[1:5])
print(degrees[1:]) # Hasta el final
print(degrees[-2:])
print(degrees[2])
print(degrees[2:3])
print(type(degrees[2:3]))
# Out:
# [15, 26]
# [34, 15, 26, 18]
# [34, 15, 26, 18, 22]
# [18, 22]
# 15
# [15]
# <class 'list'>

# %%
degrees = [22, 34, 15, 26, 18, 20]
print(degrees)
# Out:
# [22, 34, 15, 26, 18, 20]

# %%
degrees[-1:-5:-3]
# Out:
# [20, 15]

# %%
segunda_lista = degrees[2:4]
segunda_lista
# Out:
# [15, 26]

# %% [markdown]
# ### Modificar elementos
# Las listas son mutables, por lo que podremos modificarlas

# %%
print(months)

months[2] = "Abril"
print(months)
# Out:
# ['Enero', 'Febrero', 'Marzo']
# ['Enero', 'Febrero', 'Abril']

# %% [markdown]
# ### Añadir elementos
# Se añade al final de la lista si usamos `append`, o si queremos en un lugar concreto, mediante `insert`

# %%
motos = ['honda', 'yamaha', 'suzuki']
print(motos)

motos.append('ducati')
print(motos)

# Inserta en una posición concreta y desplaza el resto
motos.insert(2, 'kawasaki')
print(motos)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'kawasaki', 'suzuki', 'ducati']

# %%
motos = []

motos.append('ducati')
print(motos)
# Out:
# ['ducati']

# %%
motos = ['honda', 'yamaha', 'suzuki']
print(len(motos))
# Out:
# 3

# %%
print(motos.append("ducati"))
print(motos)
# Out:
# None
# ['honda', 'yamaha', 'suzuki', 'ducati']

# %%
print(motos)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']

# %% [markdown]
# ### Eliminar elementos
# Para eliminar elementos se usar `remove`. Si no existe, da error, así que cuidado con esta sentencia.
#
# En ocasiones resulta útil quedarnos con el elemento eliminado. Para ello usamos `pop()`, que elimina el elemento que le indiquemos, y además devuelve ese elemento por lo que podremos guardarlo en una variable para usarlo después.

# %%
edades = [23,"58",34]
print(edades.remove("58"))
print(edades)
# Out:
# None
# [23, 34]

# %%
cars = ['VW', 'Seat', 'BMW', 'VW']
print(cars)

# Borra siempre la primera ocurrencia que encuentra, NO BORRA TODAS
print(cars.remove('VW'))
print(cars)
# print(cars.remove('VW'))
# print(cars)
# Out:
# ['VW', 'Seat', 'BMW', 'VW']
# None
# ['Seat', 'BMW', 'VW']

# %%
cars
# Out:
# ['Seat', 'BMW', 'VW']

# %%
# cars.pop(1)

# %%
cars_removed = []
cars_removed.append(cars.pop(1))
print(cars_removed)
print(cars)
# Out:
# ['BMW']
# ['Seat', 'VW']

# %%
print(cars.pop(1))
print(cars)
# Out:
# VW
# ['Seat']

# %%
cars = ['VW', 'Seat', 'BMW', 'VW']
cars.pop(1)
print(cars)
# Out:
# ['VW', 'BMW', 'VW']

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES remove</h3>
#
#  </td></tr>
# </table>

# %%
cars = ['VW', 'Seat', 'BMW', 'VW']
cars.remove("Audi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 cars = ['VW', 'Seat', 'BMW', 'VW']
# ----> 2 cars.remove("Audi")
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ### Métodos: ordenar, tamaño, invertir orden, ocurrencia
# En este apartado veremos los métodos más útiles, pero podrás consultar el resto en [este enlace](https://www.w3schools.com/python/python_ref_list.asp)

# %%
degrees = [22, 34, 15, 26, 18, 22]
print(degrees)
print(sorted(degrees))
print(degrees)
# Out:
# [22, 34, 15, 26, 18, 22]
# [15, 18, 22, 22, 26, 34]
# [22, 34, 15, 26, 18, 22]

# %%
degrees = [22, 34, 15, 26, 18, 22]
print(degrees)

# Ordenar
# Esta funcion muestra la lista ordenada pero la lista no cambia, solo modifica la visualización. Sirve para otro tipo de colecciones
print(sorted(degrees))
print(sorted(degrees, reverse = True))
print(degrees)
# Este método ordena la lista pero además la modifica. Solo sirve para listas
print(degrees.sort())
print(degrees)

print(degrees.reverse())
print(degrees)

degrees.count(22)
# Out:
# [22, 34, 15, 26, 18, 22]
# [15, 18, 22, 22, 26, 34]
# [34, 26, 22, 22, 18, 15]
# [22, 34, 15, 26, 18, 22]
# None
# [15, 18, 22, 22, 26, 34]
# None
# [34, 26, 22, 22, 18, 15]
# 2

# %%
numeros = [13, 36, 99, 64, 42, 25, 9]

# Necesitanmos una nueva variable para que el resultado de la función se guarde
numeros_2 = sorted(numeros)
print(numeros_2)

# En este caso, aplicar la función a la lista original la modifica
numeros.sort(reverse = True)
print(numeros)
# Out:
# [9, 13, 25, 36, 42, 64, 99]
# [99, 64, 42, 36, 25, 13, 9]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES indice</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Mucho cuidado cuando accedemos a los elementos de la lista. Es un error muy habitual acceder a un índice que no existe en la lista.
#
# Si estamos accediendo al ultimo elemento, en vez de poner el numero de su indice, poner mejor `-1`, y asi evitamos errores

# %% [markdown]
# Si tenemos este tipo de errores y no sabemos resolverlos, lo mejor es imprimir la longitud de la lista, y todos los elementos.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio de listas</h3>
#
# Piensa en al menos 3 personas que invitarías a cenar
# <ol>
#     <li>Utiliza la lista de invitados para imprimir cada uno por pantalla y su índice, mediante un bucle</li>
#     <li>Ordena alfabéticamente tu lista de invitados</li>
#     <li>¿Quién es el primer invitado de la lista?</li>
#     <li>Te llama uno de ellos a última hora, que no va a poder asistir. Elimínalo de la lista</li>
#     <li>Por suerte te ha llamado un amigo que no iba a asistir y al final sí puede. Añádelo a mitad de la lista</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
lista_invitados = ["Juan", "Jaime", "Jose"]

for ind, elem in enumerate(lista_invitados):
    print(f"Indice: {ind} ---------- Invitado: {elem}")

lista_invitados_2 = sorted(lista_invitados)
print(lista_invitados_2)

lista_invitados.sort()
print(lista_invitados)

lista_invitados.remove("Jose")
print(lista_invitados)

lista_invitados.insert(1, "Andoni")
print(lista_invitados)

lista_invitados.pop(0)
print(lista_invitados)

lista_invitados_removed = []
lista_invitados_removed.append(lista_invitados.pop(0))
print(lista_invitados_removed)
# Out:
# Indice: 0 ---------- Invitado: Juan
# Indice: 1 ---------- Invitado: Jaime
# Indice: 2 ---------- Invitado: Jose
# ['Jaime', 'Jose', 'Juan']
# ['Jaime', 'Jose', 'Juan']
# ['Jaime', 'Juan']
# ['Jaime', 'Andoni', 'Juan']
# ['Andoni', 'Juan']
# ['Andoni']

# %% [markdown]
# ## 2. Tuplas
# Muy similares a las listas. Si en Notebooks anteriores definíamos a las listas como ordenadas y mutables, las tuplas son ordenadas e inmutables.
#
# * **Inmutables**: una vez creada la tupla con sus elementos iniciales, no se puede modificar
# * **Ordenadas**: podemos acceder a sus elementos a través del índice y reordenar la tupla según queramos
#
# Las tuplas se suelen usar para pequeñas colecciones de datos que no van a cambiar a lo largo del programa, como es el caso de las constantes.
#
# Si las listas se construían mediante corchetes `[]`, las tuplas lo hacen con los paréntesis `()`

# %%
primera_tupla = (3, "text")
print(primera_tupla)
print(type(primera_tupla))
# Out:
# (3, 'text')
# <class 'tuple'>

# %% [markdown]
# Los paréntesis ya se usan para reordenar operaciones `5 * (3 + 4)`, por lo que hay que añadir una coma cuando definamos una tupla con un único elemento, sino Python lo interpretará como un número.

# %%
otra_tupla = (1)
print(otra_tupla)
print(type(otra_tupla))
# Out:
# 1
# <class 'int'>

# %%
otra_tupla = (1,)
print(otra_tupla)
print(type(otra_tupla))
# Out:
# (1,)
# <class 'tuple'>

# %%
tupla_anid = (1, 2, 3, ("A", "B", "C"))
print(tupla_anid)

print(tupla_anid[0])

for i in tupla_anid:
    print(i)
    
print(tupla_anid[0:2])

print(len(tupla_anid))
# Out:
# (1, 2, 3, ('A', 'B', 'C'))
# 1
# 1
# 2
# 3
# ('A', 'B', 'C')
# (1, 2)
# 4

# %%
tupla_anid = (1, 2, 3, ("A", "B", "C"))

tupla_anid[3][0]
# Out:
# 'A'

# %%
tupla_anid_2 = (("A", "B", "C"), ("D", "E", "F"))
for i in range(len(tupla_anid_2)):
    print(i, ": ", tupla_anid_2[i])
    print("---------------------")
    for j in tupla_anid_2[i]:
        print(j)
# Out:
# 0 :  ('A', 'B', 'C')
# ---------------------
# A
# B
# C
# 1 :  ('D', 'E', 'F')
# ---------------------
# D
# E
# F

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES tuplas</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Cuidado que las tuplas son inmutables, y una vez creadas no las podrás modificar después

# %%
# Las tuplas son inmutables, no se puede sustituir una posición
tupla_error = (1,2,3)
tupla_error[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Las tuplas son inmutables, no se puede sustituir una posición
#       2 tupla_error = (1,2,3)
# ----> 3 tupla_error[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Si queremos añadir elementos, podemos meterlos en otra tupla y sumarlas para que se concatenen
tupla1 = (1,2,3)
tupla2 = (4,5,6)
tupla3 = (7, 8, 9)
tupla4 = tupla1 + tupla2 + tupla3

print(tupla4)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
tupla4
# Out:
# (1, 2, 3, 4, 5, 6, 'Diego', 'Andrea')

# %%
# Como la tupla es inmutable, convierte la salida en una lista
print(sorted(tupla4))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### Listas y tuplas
# Podemos combinar listas y tuplas que no tendremos ningún problema, siempre y cuando respetemos las propiedades de cada tipo de dato.

# %%
mi_tupla = ("Naranjas", "Limones")
frutas = ["Manzanas", mi_tupla, "Fresas"]
print(frutas)
print(frutas[0])
print(frutas[-1])
print(frutas[1][0])
# Out:
# ['Manzanas', ('Naranjas', 'Limones'), 'Fresas']
# Manzanas
# Fresas
# Naranjas

# %%
# Se hace una lista de la tupla, pero aquí aun no se hace efectivo el cambio
print(frutas)
list(frutas[1])
print(frutas[1])
print(frutas)
# Out:
# ['Manzanas', ['Naranjas', 'Limones'], 'Fresas']
# ['Naranjas', 'Limones']
# ['Manzanas', ['Naranjas', 'Limones'], 'Fresas']

# %%
new_var = frutas[1]
new_var = list(new_var)
print(new_var)
print(type(new_var))
# Out:
# ['Naranjas', 'Limones']
# <class 'list'>

# %%
print(type(frutas))
print(frutas)
print(type(frutas[1]))
print((frutas[1]))

print(frutas)

# Aquí sí se hace efectivo el cambio
frutas[1] = list(frutas[1])
print(frutas[1])
print(frutas)
# Out:
# <class 'list'>
# ['Manzanas', ('Naranjas', 'Limones'), 'Fresas']
# <class 'tuple'>
# ('Naranjas', 'Limones')
# ['Manzanas', ('Naranjas', 'Limones'), 'Fresas']
# ['Naranjas', 'Limones']
# ['Manzanas', ['Naranjas', 'Limones'], 'Fresas']

# %%
frutas.append("Melocoton")
print(frutas)
frutas[1].append("Otro melocoton")
# Out:
# ['Manzanas', ('Naranjas', 'Limones'), 'Fresas', 'Melocoton']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 3
#       1 frutas.append("Melocoton")
#       2 print(frutas)
# ----> 3 frutas[1].append("Otro melocoton")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
mi_tupla_tolist = list(mi_tupla)
print(mi_tupla_tolist)
# Out:
# ['Naranjas', 'Limones']

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio de tuplas</h3>
#
#
# <ol>
#     <li>Crea una tupla con un único valor. Comprueba su tipo</li>
#     <li>Crea otra tupla con 3 elementos</li>
#     <li>Añadele (como puedas) a la primera tupla, los tres elementos de la segunda</li>
#     <li>Obtén una cuarta tupla a partir de los dos primeros valores de la tupla creada del apartado anterior</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
tupla_1 = (1,)
tupla_2 = (2, 3, 4)
tupla_suma = tupla_1 + tupla_2
print(tupla_suma)
tupla_4 = (tupla_suma[2:])
print(tupla_4)
tupla_5 = (tupla_suma[0:2])
print(tupla_5)
# Out:
# (1, 2, 3, 4)
# (3, 4)
# (1, 2)

# %%
tupla_1 = (1,)
tupla_2 = (2, 3, 4)
tupla_1 = tupla_1 + tupla_2
print(tupla_1)
tupla_4 = (tupla_1[2:])
print(tupla_4)
tupla_5 = (tupla_1[0:2])
print(tupla_5)
# Out:
# (1, 2, 3, 4)
# (3, 4)
# (1, 2)

# %% [markdown]
# ## 3. Diccionarios
#
# Las listas y los diccionarios son de lejos las colecciones más usadas.
#
# Un diccionario es similar a un json.
#
# La principal caracteristica es que son colecciones desordenadas, a los elementos se accede por (clave,valor), no por posición.
#
# En este tipo de colecciones no solo podemos agrupar datos, sino que tenemos la posibilidad de establecer una relación entre los mismos, con la forma **clave: valor**.
#
# La sintaxis  es mediante llaves `{}`
#
# > nombre_diccionario = {clave1: valor1, clave2: valor2, clave3: valor3}
#
# Si veíamos que las listas son elementos mutables y y ordenadas, y las tuplas inmutables y ordenadas, los diccionarios son:
#
# * **Mutables**: podemos modificar sus elementos
# * **Desordenado**: la potencia de acceso de los diccionarios es su formato clave-valor, no su orden. Aun así, el dicionario conserva el orden de los elemento según los vamos insertando.
#
# Vamos a declarar un diccionario en el que definiremos elementos de un coche

# %%
lista_coche = ["Gris", "VW", 1500, True]
print(lista_coche[0])
# Out:
# Gris

# %%
# Normalmente un diccionario se tabula para mejorar la visualización
# Independientemente de dónde se encuentre una clave accedemos al valor por esa clave, no por la posición  
coche = {"color": "Gris",
        "marca": "VW",
        "peso": 1500,
        "Cambio automatico": True}
print(coche)
# Out:
# {'color': 'Gris', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True}

# %%
print(type(coche))
# Out:
# <class 'dict'>

# %%
coche["color"]
# Out:
# 'Gris'

# %%
# Los valores de un diccionario pueden ser listas, tuplas, sets...
coches = {
    "id": [1,2,3],
    "color": ["rojo",'azul',"gris"]
}

# %%
import pandas as pd
pd.DataFrame(coches)
# Out:
#    id color
# 0   1  rojo
# 1   2  azul
# 2   3  gris

# %%
coches['color'][1]
# Out:
# 'azul'

# %%
coche = {"color": "Gris",
        "marca": "VW",
        "peso": 1500,
        "Cambio automatico": True,
        (1,5): {"Hola": [1,3]}}

# %%
print(list(coche.keys()))
print(list(coche.values()))
# Out:
# ['color', 'marca', 'peso', 'Cambio automatico']
# ['Gris', 'VW', 1500, True]

# %%
coche
# Out:
# {'color': 'Gris',
#  'marca': 'VW',
#  'peso': 1500,
#  'Cambio automatico': True,
#  (1, 5): {'Hola': [1, 3]}}

# %%
for clave in coche:
    print(clave, ": ", coche[clave])
# Out:
# color :  Gris
# marca :  VW
# peso :  1500
# Cambio automatico :  True

# %%
for clave in coche:
    print(clave, "-------------", coche[clave])
# Out:
# color ------------- Gris
# marca ------------- VW
# peso ------------- 1500
# Cambio automatico ------------- True
# (1, 5) ------------- {'Hola': [1, 3]}

# %%
print(*coche)
# Out:
# color marca peso Cambio automatico

# %%
# transformación de un diccionario en lista, se pierden las claves
list(coche.values())
# Out:
# ['Gris', 'VW', 1500, True, {'Hola': [1, 3]}]

# %%
coche = {"color": "Gris",
        "marca": "VW",
        "peso": 1500,
        "Cambio automatico": True,
        # Aquí el valor es un diccionario, asociado a una clave que es una tupla, el valor de ese diccionario anidado es una lista
        (1,5): {"Hola": [1,3]}}  

## Acceso al segundo elemento la lista del diccionario anidado
coche[(1,5)]['Hola'][1]
# Out:
# 3

# %% [markdown]
# Se puede almacenar todo tipo de datos: numero, cadena, booleano, listas, tuplas, diccionarios...
#
# Cuando declaremos el diccionario, lo podemos hacer en una sola linea `coche = {"color"="Gris", "marca"...}`, aunque se recomienda por sencillez a la hora de leer el código, realizar esta acción en varias líneas. Si escribimos el primer elemento y presionamos enter, Jupyter introduce automáticamente la tabulación.

# %% [markdown]
# ### Acceso, modificación, añadir, eliminar

# %%
coche
# Out:
# {'color': 'Gris',
#  'marca': 'VW',
#  'peso': 1500,
#  'Cambio automatico': True,
#  (1, 5): {'Hola': [1, 3]}}

# %%
coche['color']
# Out:
# 'Gris'

# %%
coche['color'] = coche['color'] + " Blanco"
print(coche)
# Out:
# {'color': 'Gris Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}}

# %%
# Acceso
print(coche['Cambio automatico'])

# Modificar
coche['color'] = "Blanco"
print(coche)

# Añadir
coche['puertas'] = 4
print(coche)

# Eliminar
# del coche['puertas']
print(coche.pop('puertas'))
print(coche)
# Out:
# True
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}}
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}, 'puertas': 4}
# 4
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}}

# %%
print(list(coche.keys()))
print(list(coche.values()))

print(coche)
# Out:
# ['color', 'marca', 'peso', 'Cambio automatico', (1, 5)]
# ['Gris Blanco', 'VW', 1500, True, {'Hola': [1, 3]}]
# {'color': 'Gris Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}}

# %% [markdown]
# Para más detalle de los métodos de los diccionario puedes [consultar la documentación](https://www.w3schools.com/python/python_ref_dictionary.asp)

# %%
# Podemos empezar tambien mediante un diccionario vacío
tienda = {}
tienda['Direccion'] = ["Avenida 1", "Avenida 2"]
tienda['Tamaño'] = [110, 90]
print(tienda)
# Out:
# {'Direccion': ['Avenida 1', 'Avenida 2'], 'Tamaño': [110, 90]}

# %%
lista_total = ["Avenida 1", "Avenida 2"] + [110, 90]
print(lista_total)
# Out:
# ['Avenida 1', 'Avenida 2', 110, 90]

# %%
my_dict = {}

for i, elem in enumerate(lista_total):
    my_dict[i] = elem

print(my_dict)
# Out:
# {0: 'Avenida 1', 1: 'Avenida 2', 2: 110, 3: 90}

# %%
my_dict = {}

for i, elem in enumerate(lista_total):
    if i < 2:
        my_dict['Dirección'] = elem
    else:
        my_dict['Tamaño'] = elem

print(my_dict)
# Out:
# {'Dirección': 'Avenida 2', 'Tamaño': 90}

# %%
print(my_dict[3])
print(lista_total[3])
# Out:
# 90
# 90

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES en diccionarios</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Si hay una clave que no existe en el diccionario, saltará un error.
#
# En este caso, el error es bastante intuitivo: `KeyError`, no encuentra la clave

# %%
coche = {"color": "Gris",
        "marca": "VW"}
coche["peso"]
print("Hola")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 3
#       1 coche = {"color": "Gris",
#       2         "marca": "VW"}
# ----> 3 coche["peso"]
#       4 print("Hola")
#
# KeyError: 'peso'

# %% [markdown]
# **¿Cómo solventar esto?** Sirmpre tienes la opción de usar el bloque `try/except`, pero en este caso, los diccionarios tienen una solución más elegante: `get(clave, valor si no existe)`

# %%
# coche['peso'] = 500

# %%
print(coche['peso'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 print(coche['peso'])
#
# KeyError: 'peso'

# %%
a = coche.get("peso")
print(a)
print("Hola")
# Out:
# None
# Hola

# %%
a = coche.get("ruedas", False)
if a == False:
    print("No hay ruedas")
# Out:
# No hay ruedas

# %% [markdown]
# ### Iterar
# Que el diccionario no esté ordenado, no quiere decir que no podamos iterar sus elementos, ya que también es un **interable**, como los son las listas o las tuplas.

# %%
coche = {"color": "Gris",
        "marca": "VW"}

for i in coche:
    print(i, coche[i])
# Out:
# color Gris
# marca VW

# %%
for i in coche.values():
    print(i)
# Out:
# Gris
# VW

# %%
for clave, valor in coche.items():
    print(clave, valor)
# Out:
# color Gris
# marca VW

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio de diccionarios</h3>
#
#
# <ol>
#     <li>Crea un diccionario con las caracteristicas de un televisor: tamaño(float), smarttv(bool) y marca(str)</li>
#     <li>Añade otra característica del tv</li>
#     <li>Modifica una de ellas</li>
#     <li>Imprime por pantalla sus claves, valores.</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
televisor = {"tamaño": 32.0,
            "smarttv": True,
            "marca": "Samsumg",}

print(televisor)
print(type(televisor))

televisor["resolución"] = "4k"
print(televisor)

televisor["tamaño"] = 52.0
print(televisor)

print(televisor["smarttv"])
print(televisor.get("smarttv"))

print("***********")

print("CLAVES, VALORES 01")

for i in televisor:
    print(i, "; ", televisor[i])

print("***********")

print("CLAVES, VALORES 02")

for clave, valor in televisor.items():
    print(clave, ": ", valor)

print("***********")

print("CLAVES, VALORES ---> FORMA INCORRECTA")
print("LA CLAVE SE PIERDE")

for clave, valor in enumerate(televisor):
    print(clave, ": ", valor)
# Out:
# {'tamaño': 32.0, 'smarttv': True, 'marca': 'Samsumg'}
# <class 'dict'>
# {'tamaño': 32.0, 'smarttv': True, 'marca': 'Samsumg', 'resolución': '4k'}
# {'tamaño': 52.0, 'smarttv': True, 'marca': 'Samsumg', 'resolución': '4k'}
# True
# True
# ***********
# CLAVES, VALORES 01
# tamaño ;  52.0
# smarttv ;  True
# marca ;  Samsumg
# resolución ;  4k
# ***********
# CLAVES, VALORES 02
# tamaño :  52.0
# smarttv :  True
# marca :  Samsumg
# resolución :  4k
# ***********
# CLAVES, VALORES ---> FORMA INCORRECTA
# LA CLAVE SE PIERDE
# 0 :  tamaño
# 1 :  smarttv
# 2 :  marca
# 3 :  resolución

# %% [markdown]
# ## 4. Sets
# Otra colección *bulit-in* de Python, compuesta por un conjunto de *claves*. Muy parecidos a los diccionarios. Tienen las siguientes características:
# * **Mutables**: podemos modificarlos una vez se hayan creado
# * **No ordenados**
# * **Elementos únicos**: se compone de un conjunto de claves únicas
#
# **¿Cuándo usar sets?** Cuando estemos buscando unicidad en nuestros datos y no nos importe el orden.
#
# Te dejo por aquí [la documentación](https://docs.python.org/2/library/sets.html) para realizar consultas sobre los sets
#
# Su sintaxis es:
# >```Python
# > mi_set = {elemento1, elemento2, elemento3}
# >```
#
# Tiene una sintaxis muy parecida a la de los diccionarios, pero en este caso no se utilizan los `:`.

# %%
colores = {"rojo", "azul", "blanco"}
print(colores)

colores2 = {"rojo", "azul", "blanco", "rojo"}
print(colores2)

len(colores2)
# Out:
# {'blanco', 'azul', 'rojo'}
# {'blanco', 'azul', 'rojo'}
# 3

# %% [markdown]
# Los elementos del set son unicos, por lo que si en la declaración, o posteriormente añadiendo elementos hubiese algún duplicado, el set lo ignoraría. Es más, cuando aplicas el `len`, muestra la cantidad de valores únicos que tiene.

# %%
dias = {'dia', 4}
print(dias)

dias = set()
dias.add("Lunes")
dias.add("Martes")
print(dias)

dias.remove("Martes")
print(dias)

print("Lunes" in dias)
print("Viernes" not in dias)

for i in dias:
    print(i)
# Out:
# {4, 'dia'}
# {'Lunes', 'Martes'}
# {'Lunes'}
# True
# True
# Lunes

# %% [markdown]
# Para comprobar si dos sets tienen los mismos elementos

# %%
lista = [1,2,3,5]
lista[1]
# Out:
# 2

# %%
set1 = {1,3,5,1,7,6,1,3}
set2 = {5,1,3,7,6}

set1 == set2
# Out:
# True

# %%
# Si no se le especifica una posición dentro de pop(), elminina un elemento aleatoriamente
set2.pop()
print(set2)
# Out:
# {3, 5, 6, 7}

# %%
print(set1)
print(set2)
# Out:
# {1, 3, 5, 6, 7}
# {3, 5, 6, 7}

# %%
if 1 in set1:
    print("hay un 1")
# Out:
# hay un 1

# %%
set1 = {1,3,5,1,7,6,1,3}
set2 = {5,1,3,10}

print(set1)
print(set2)
print('-'*10)

# Intersección (se imprimen los valores comunes entre los 2 sets)
print(set1 & set2) # and
# Unión (se imprimen todos los elementos que están en cualquiera de los dos conjuntos (sin repetir))
print(set1 | set2) # or
# Diferencia (se imprimen los elementos que están en set1 pero no en set2)
print(set1 - set2) 
# Diferencia inversa (se imprimen los elementos que están en set2 pero no en set1)
print(set2 - set1)
# Out:
# {1, 3, 5, 6, 7}
# {1, 10, 3, 5}
# ----------
# {1, 3, 5}
# {1, 3, 5, 6, 7, 10}
# {6, 7}
# {10}

# %% [markdown]
# ## 5. Conversiones entre colecciones
#
# ### De lista

# %%
list_1 = [1,2,3,3,3,3,3,3,3]
print(list_1)

# A tupla
tuple_1 = tuple(list_1)
print(tuple_1)

# A set
print(set(list_1))
# Out:
# [1, 2, 3, 3, 3, 3, 3, 3, 3]
# (1, 2, 3, 3, 3, 3, 3, 3, 3)
# {1, 2, 3}

# %% [markdown]
# ### De Tupla

# %%
tupla_1 = (1,2,3)
print(tupla_1)

# A lista
print(list(tupla_1))
lista_tup = list(tupla_1)
print(lista_tup)

# A set
print(set(tupla_1))
set_tup = set(tupla_1)
print(set_tup)

# A diccionario
lista_tuplas = [("Ciudad", "Madrid"), ("Tiempo", "nublado")]
print(dict(lista_tuplas))
dic_lista_tup = dict(lista_tuplas)
print(dic_lista_tup)
# Out:
# (1, 2, 3)
# [1, 2, 3]
# [1, 2, 3]
# {1, 2, 3}
# {1, 2, 3}
# {'Ciudad': 'Madrid', 'Tiempo': 'nublado'}
# {'Ciudad': 'Madrid', 'Tiempo': 'nublado'}

# %%
tupla = (1,2,2,3,3,4)
my_dict = {}
for i, elem in enumerate(tupla):
    my_dict[i] = elem

print(my_dict)
# Out:
# {0: 1, 1: 2, 2: 2, 3: 3, 4: 3, 5: 4}

# %% [markdown]
# ### De diccionario

# %%
tupla_dict = [("Ciudad", "Madrid"), ("Tiempo", "nublado")]
dict_1 = dict(tupla_dict)
print(dict_1)

# A lista (solo se conservan las claves)
print("LISTA: ", list(dict_1))

# A tupla (solo se conservan las claves)
print("TUPLA: ",tuple(dict_1))

# A set (solo se conservan las claves)
print("SET: ", set(dict_1))


# A lista (se crea tupla dentro de lista)
print("LISTA: ", list(dict_1.items()))

# A tupla (se crea tupla dentro de tupla)
print("TUPLA: ", tuple(dict_1.items()))

# A set (se crea tupla dentro de set)
print("SET: ", set(dict_1.items()))
# Out:
# {'Ciudad': 'Madrid', 'Tiempo': 'nublado'}
# LISTA:  ['Ciudad', 'Tiempo']
# TUPLA:  ('Ciudad', 'Tiempo')
# SET:  {'Tiempo', 'Ciudad'}
# LISTA:  [('Ciudad', 'Madrid'), ('Tiempo', 'nublado')]
# TUPLA:  (('Ciudad', 'Madrid'), ('Tiempo', 'nublado'))
# SET:  {('Tiempo', 'nublado'), ('Ciudad', 'Madrid')}

# %% [markdown]
# CONVERSIONES DE DICCIONARIO A LISTA CREANDO UNA LISTA VACÍA E ITERANDO SOBRE EL DICCIONARIO

# %%
mi_list = []

for clave, valor in dict_1.items():
    mi_list.append(clave)
    mi_list.append(valor)

mi_list
# Out:
# ['Ciudad', 'Madrid', 'Tiempo', 'nublado']

# %%
mi_list = []

for i in dict_1:
    mi_list.append(i)
    mi_list.append(dict_1[i])

mi_list
# Out:
# ['Ciudad', 'Madrid', 'Tiempo', 'nublado']

# %%
for i in dict_1:
    print(i)
for i in dict_1.keys():
    print(i)
for i in list(dict_1):
    print(i)
# Out:
# Ciudad
# Tiempo
# Ciudad
# Tiempo
# Ciudad
# Tiempo

# %% [markdown]
# Se queda únicamente con las claves, y perdemos los valores. Para no perder la informacion:

# %%
print(dict_1.keys())
print(dict_1.values())
print(dict_1.items())
# Out:
# dict_keys(['Ciudad', 'Tiempo'])
# dict_values(['Madrid', 'nublado'])
# dict_items([('Ciudad', 'Madrid'), ('Tiempo', 'nublado')])

# %% [markdown]
# ### De Set

# %%
set_1 = {1,2,3}
print(set_1)

print(list(set_1))
print(tuple(set_1))
# Out:
# {1, 2, 3}
# [1, 2, 3]
# (1, 2, 3)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES en conversiones</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# El diccionario suele dar problemas cuando intentamos realizar conversiones entre colecciones, ya que es la estrutura más compleja.

# %%
mi_tupla = (1,2,3)
dict(mi_tupla)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Carpeta_profesor\2309_dsft_thebridge\1-Ramp_Up\Python\3-Colecciones\Teoria\Colecciones.ipynb Cell 121 line 2
#       <a href='vscode-notebook-cell:/d%3A/Carpeta_profesor/2309_dsft_thebridge/1-Ramp_Up/Python/3-Colecciones/Teoria/Colecciones.ipynb#Y213sZmlsZQ%3D%3D?line=0'>1</a> mi_tupla = (1,2,3)
# ----> <a href='vscode-notebook-cell:/d%3A/Carpeta_profesor/2309_dsft_thebridge/1-Ramp_Up/Python/3-Colecciones/Teoria/Colecciones.ipynb#Y213sZmlsZQ%3D%3D?line=1'>2</a> dict(mi_tupla)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %% [markdown]
# ## 6. Comprensión de listas
#
# Las listas pueden crearse también por comprensión (en inglés, *comprehension*). Esto tiene mucha relación con la definición de conjuntos por comprensión de las matemáticas. Sea por ejemplo, en matemáticas esta expresión:
# $$ S = \{x^2 |\ x \in [3, 7), x \  impar\}$$
# Esta expresión define un conjunto $ S = \{9, 25\}$, puesto que el intervalo es abierto por la derecha, con lo que solo comprende los números 3, 4, 5 y 6, pero la condición dice que solo tengamos en cuenta los impares, es decir, 3 y 5, y la expresión del principio dice que tomemos los cuadrados. Recordando que para saber si un número es par o impar usamos en Python el operador módulo (`%`), esto se puede escribir (definiendo una lista `s` en lugar de un conjunto) como:

# %%
list_comp = []
for x in range(3,7):
    if x % 2 == 1:
        list_comp.append(x**2)

print(list_comp)
# Out:
# [9, 25]

# %%
list_comp = []
for x in range(3,7):
    if x % 2 != 0:
        list_comp.append(x**2)

print(list_comp)
# Out:
# [9, 25]

# %%
list_comp = [x**2 for x in range(3, 7) if x % 2 == 1]
print(list_comp)
# Out:
# [9, 25]

# %%
list_comp = [x**2 for x in range(3, 7) if x % 2 != 0]
print(list_comp)
# Out:
# [9, 25]

# %%
list_comp = [x**2 if x % 2 == 1 else x for x in range(3, 7)]
print(list_comp)
# Out:
# [9, 4, 25, 6]

# %%
list_comp = [x + "-encontrada" for x in "Hola mundo" if x == "o"]
list_comp
# Out:
# ['o-encontrada', 'o-encontrada']

# %% [markdown]
# Si tenemos un trozo de código que define una lista de este tipo:
# ``` python
# nueva_lista = []
# for e in vieja_lista:
#     if filtro(e):
#         nueva_lista.append(transformacion(e))
# ```
# Se puede escribir, usando comprensión, como:
# ```python
# nueva_lista = [transformacion(e) for e in vieja_lista if filtro(e)]
# ```
#
# La definición de listas por comprensión es muy cómoda, compacta y expresiva. No obstante, no debemos abusar de ella; si la expresión que escribimos es muy compleja se puede volver muy difícil de leer. En ese caso sería preferible la definición "clásica" de la lista.
#
# Vamos a ver esto con un ejemplo. Supongamos una lista de `edades`, de la que queremos obtener una nueva lista, `mayores_edad` con las que sean mayores o iguales que 21. Escribiríamos:

# %%
edades = [19, 20, 18, 21, 19, 25, 16]
print(edades)
mayores_edad = [x for x in edades if x >= 18]
print(mayores_edad)
# Out:
# [19, 20, 18, 21, 19, 25, 16]
# [19, 20, 18, 21, 19, 25]

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio list comprehension</h3>
#
# Prueba a definir una lista temperaturas_menores, a partir de la lista temperaturas, con temperaturas menores que 27 grados, guardando los valores con un redondeo de 0 decimales.
#
#          temperaturas = [25.2, 24.9, 25.2, 26.7, 28.6, 29.5, 29.7]
#
#  </td></tr>
# </table>

# %%
temperaturas = [25.2, 24.9, 25.2, 26.7, 28.6, 29.5, 29.7]

# %%
temperaturas_menores = [round(x, 0) for x in temperaturas if x < 27]
print(temperaturas_menores)
# Out:
# [25.0, 25.0, 25.0, 27.0]

# %% [markdown]
# ## 7. Resumen

# %%
# Listas
print("Listas")
nums = [6, 2, 8, 3, 4, 5, 5]

# Tamaño
print(len(nums))

# Acceso
print(nums[2])
print(nums[-1])

# Acceso por indice
print(nums.index(5))
nums.append('numeros')
print(nums)

# Eliminar
nums.remove("numeros")
print(nums)

# Ordenar
nums.sort()
print(nums)

# Tamaño de la lista
print(len(nums))

# Invertir el orden
nums.reverse()
print(nums)

# Ocurrencia de un valor
print(nums.count(22))

# %%
# Tuplas
primera_tupla = (3, "text")

# Anidacion de tuplas
tupla_anid = (1, 2, 3, ("A", "B", "C"))
print(tupla_anid)

# El acceso es como en las listas
print(tupla_anid[0])

# Tambien son elementos iterables
for i in tupla_anid:
    print(i)
    
# El slicing también funciona igual
print(tupla_anid[0:2])

# Longitud de la tupla
print(len(tupla_anid))

# %%
# Diccionario
coche = {"color": "Gris",
        "marca": "VW",
        "peso": 1500,
        "Cambio automatico": True}

print(coche)

coche = {"color": "Gris",
        "marca": "VW"
        }

for i in coche: # Esta recorriendo las claves
    print(i) # Imprimimos la clave
    print(coche[i]) # Imprimimos el valor
    
# Otra menera de recorrer los elementos
for clave, valor in coche.items():
    print(clave, valor)

# %%
# Sets
colores = {"rojo", "azul", "blanco"}
print(colores)

# Mira lo que ocurre cuando ponemos duplicados
colores2 = {"rojo", "azul", "blanco", "rojo"}
print(colores2)

# El len tambien funciona aqui
len(colores2)

# Crear un set vacio. No se crea con {}, ya que si no, sería un diccionario.
dias = set()
print(dias)

# Añadir elementos
dias.add("Lunes")
dias.add("Martes")
dias.add("Miercoles")
print(dias)

# Eliminar elementos
dias.remove("Miercoles")
print(dias)

# Buscar elementos
print("Lunes" in dias)
print("Viernes" not in dias)

# Tambien es un iterable
for i in dias:
    print(i)

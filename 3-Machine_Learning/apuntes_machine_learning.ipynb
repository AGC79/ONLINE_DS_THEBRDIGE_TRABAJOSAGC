# %% [markdown]
# # APUNTES MACHINE LEARNING

# %% [markdown]
# Los modelos predicitivos tienen que funcionar siempre con valores numéricos.
#
# Se depende de la calidad de los datos que tenenmos.
#
# La misión es entrenar a las máquinas, es la base de la IA. Una IA es una máquina que hace calculos estadísitcos por detras.
#
# LLM es un asisntente para conversar con una persona.
#
# Computer Vision (Visión por Computador) es un área de la inteligencia artificial que permite a las máquinas ver, interpretar y comprender imágenes y vídeos del mundo real, de forma similar a como lo hace el ojo humano.
#
# Toda IA se basa en patrones de datos.
#
# NLP (Natural Language Processing), o Procesamiento del Lenguaje Natural, es una rama de la inteligencia artificial que permite a las máquinas entender, interpretar, generar y trabajar con el lenguaje humano.
#
# 🔧 ¿Cómo funciona?
#
# El NLP combina:
#
# 1. Lingüística
#
# Gramática
#
# Estructura del lenguaje
#
# Semántica
#
# 2. Machine Learning / Deep Learning
#
# Modelos estadísticos
#
# Redes neuronales (transformers, LSTM, etc.)
#
# 3. Grandes cantidades de datos
#
# Textos reales para aprender patrones del lenguaje.
#
# 📌 Ejemplos de uso
#
# Chatbots
#
# Asistentes de voz (Siri, Alexa)
#
# Traductores automáticos
#
# Análisis de comentarios y redes sociales
#
# Corrección ortográfica automática
#
# Buscadores inteligentes
#
# Sistemas de recomendación basados en texto
#
# 🎯 En resumen
#
# NLP = IA que permite que las máquinas entiendan y generen lenguaje humano.

# %% [markdown]
# Machine Learning funciona con **datos tabulares**

# %% [markdown]
# # Regresión Lineal
#
# Una **regresión lineal** es un método estadístico y de machine learning que sirve para **modelar la relación entre una variable dependiente (lo que se quiere predecir)** y **una o más variables independientes (las que se usan para predecir)**.
#
# Se llama **lineal** porque intenta ajustar una **línea recta** (o un hiperplano, si hay varias variables) que mejor explique los datos.
#
# ---
#
# ## 📌 Idea principal
#
# La regresión lineal busca una ecuación como:
#
# \[
# y = a + b \cdot x
# \]
#
# donde:
#
# - **y** = variable que se quiere predecir
# - **x** = variable explicativa
# - **a** = intercepto
# - **b** = pendiente (cuánto cambia *y* cuando *x* aumenta)
#
# El objetivo es encontrar los valores de *a* y *b* que mejor ajusten los datos.
#
# ---
#
# ## 📊 Ejemplo intuitivo
#
# Imagina que quieres predecir el **precio de una casa** según sus **metros cuadrados**.
#
# Si dibujas un gráfico con:
#
# - X = metros cuadrados
# - Y = precio
#
# La regresión lineal buscará la **línea que mejor atraviesa los puntos** para poder predecir precios nuevos.
#
# ---
#
# ## 🎯 ¿Para qué sirve?
#
# - Predecir valores futuros
# - Medir relaciones entre variables
# - Encontrar tendencias
# - Modelos simples y rápidos para análisis
#
# ---
#
# ## 🔍 Tipos
#
# - **Regresión lineal simple**: 1 variable independiente
# - **Regresión lineal múltiple**: varias variables independientes
#
# ---
#
# ## 🧠 Resumen
#
# La regresión lineal es uno de los modelos más básicos y utilizados en Data Science:
#
# - Fácil de entender
# - Fácil de interpretar
# - Rápida de entrenar
# - Útil para predicciones y análisis
#
# Si quieres, puedo darte un ejemplo en Python con datos inventados o usando sklearn.

# %% [markdown]
# Deep Learning = redes neuronales.

# %% [markdown]
# algoritmo supervisado = basado en datos, modelos basado en un target (precio de un coche). Del paquete datos tenemos ya la variable que queremos predecir. son el 80% de la mayoria de los modelos predicitivos.
#
# algoritmo no supervisado = datos que no tienen target (dataset de Iris - pétalos, sétalos). No tienenen etiqueta, distribucionnes con las que se empaquetan paquetes.
#
# algoritmo por refuerzo: se le enseña al modelo con ciertos beneficios o refuerzos cuando un proceso sale bien (variable que pasa de 0 a 1)

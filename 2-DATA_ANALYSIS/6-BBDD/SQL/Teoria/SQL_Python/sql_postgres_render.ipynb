# %% [markdown]
# # Conexión a una base de datos PostGresSql

# %%
import psycopg2
import pandas as pd

# %%
hosting = "dpg-d4ffs6gdl3ps73cu68t0-a.frankfurt-postgres.render.com"
puerto = "5432"
nombre_db = "the_bridge_school_db"
usuario = "agc79"
pswd = "un9XpRJkW4Dau1znXbLjzQxzSmNW2Lih"

# %%
def conexion(hosting, puerto, nombre_db, usuario, pswd):
        conn = psycopg2.connect(
                host = hosting,
                port = puerto,
                dbname = nombre_db,
                user = usuario,
                password = pswd
        )
        cursor = conn.cursor()
        return conn, cursor

"""
def sql_query(cursor, query):   # SELECT * FROM TRACKS

    # Ejecuta la query
    cursor.execute(query)

    # Almacena los datos de la query 
    ans = cursor.fetchall()

    # Obtenemos los nombres de las columnas de la tabla
    names = [description[0] for description in cursor.description]

    return pd.DataFrame(ans,columns=names)
"""

def sql_insert(cursor, conn,query):
    try:
        cursor.execute(query)
        conn.commit()
        return "OK"
    except Exception as e:
        return f"error: {e}"

# %%
conexion, cursor = conexion(hosting, puerto, nombre_db, usuario, pswd)

# %%
query_libro = "SELECT * FROM libro"
query_autor = "SELECT * FROM autor"
insert_autor = "INSERT INTO autor VALUES (3, 'Orwell', 'Britanico')"
insert_libro = "INSERT INTO libro VALUES (4, '1984', 3)"

# %%
df = sql_query(cursor, query_libro)
df
# Out:
#    id_libro                              titulo  id_autor
# 0         1                Cien Años de Soledad         1
# 1         2   El Amor en los Tiempos del Cólera         1
# 2         3  Harry Potter y la Piedra Filosofal         2

# %%
df_autores = sql_query(cursor, query_autor)
df_autores
# Out:
#    id_autor                  nombre nacionalidad
# 0         1  Gabriel García Márquez   Colombiana
# 1         2            J.K. Rowling    Británica

# %%
res = sql_insert(cursor, conexion, insert_autor)
print(res)
# Out:
# OK

# %%
df_autores = sql_query(cursor, query_autor)
df_autores
# Out:
#    id_autor                  nombre nacionalidad
# 0         1  Gabriel García Márquez   Colombiana
# 1         2            J.K. Rowling    Británica
# 2         3                  Orwell    Britanico

# %%
res = sql_insert(cursor, conexion, insert_libro)
print(res)
# Out:
# OK

# %%
df = sql_query(cursor, query_libro)
df
# Out:
#    id_libro                              titulo  id_autor
# 0         1                Cien Años de Soledad         1
# 1         2   El Amor en los Tiempos del Cólera         1
# 2         3  Harry Potter y la Piedra Filosofal         2
# 3         4                                1984         3

# %%
autores = {
    "id_autor":[4,5,6],
    "nombre":["Perez Reverte", "Jose SaraMago", "Cervantes"],
    "nacionalidad":["Español", "Portugues", "Español"]
}

# %%
df_nuevos_autores = pd.DataFrame(autores)
df_nuevos_autores
# Out:
#    id_autor         nombre nacionalidad
# 0         4  Perez Reverte      Español
# 1         5  Jose SaraMago    Portugues
# 2         6      Cervantes      Español

# %% [markdown]
# "postgressql://USUARIO:CONTRASEÑA@HOST:PUERTO/NOMBRE_DB"

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("")

# %%
df_nuevos_autores.to_sql("autor", engine, if_exists="append", index= False)
# Out:
# 3

# %%
df_alumnos_ds_01 = pd.read_csv(".\\data\\query_1.csv")
df_alumnos_ds_01 = df_alumnos_ds_01.drop(columns=['Unnamed: 0'])
df_alumnos_ds_01
# Out:
#    TrackId                          Name  AlbumId  MediaTypeId  GenreId  \
# 0       15                       Go Down        4            1        1
# 1       16                   Dog Eat Dog        4            1        1
# 2       17             Let There Be Rock        4            1        1
# 3       18                Bad Boy Boogie        4            1        1
# 4       19                 Problem Child        4            1        1
# 5       20                      Overdose        4            1        1
# 6       21  Hell Ain't A Bad Place To Be        4            1        1
# 7       22             Whole Lotta Rosie        4            1        1
#
#   Composer  Milliseconds     Bytes  UnitPrice
# 0    AC/DC        331180  10847611       0.99
# 1    AC/DC        215196   7032162       0.99
# 2    AC/DC        366654  12021261       0.99
# 3    AC/DC        267728   8776140       0.99
# 4    AC/DC        325041  10617116       0.99
# 5    AC/DC        369319  12066294       0.99
# 6    AC/DC        254380   8331286       0.99
# 7    AC/DC        323761  10547154       0.99

# %%
df_alumnos_ds_02 = pd.read_csv(".\\data\\query_2.csv")
df_alumnos_ds_02
# Out:
#      Unnamed: 0  ArtistId                                               Name
# 0             0         1                                              AC/DC
# 1             1         2                                             Accept
# 2             2         3                                          Aerosmith
# 3             3         4                                  Alanis Morissette
# 4             4         5                                    Alice In Chains
# ..          ...       ...                                                ...
# 270         270       271   Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 271         271       272                             Emerson String Quartet
# 272         272       273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 273         273       274                                      Nash Ensemble
# 274         274       275                              Philip Glass Ensemble
#
# [275 rows x 3 columns]

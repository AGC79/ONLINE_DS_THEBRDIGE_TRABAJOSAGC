# %% [markdown]
# # Obtén y conoce tus datos

# %% [markdown]
# Toda la ciencia de datos se basa en unoss pasos:
#
# - Extracción - ingeniero
# - Anaítica - analista
#
# Al anáisis podría ir a producto o a desarrollo.
#
# Desde desarrollo iriía a Full Stack o ML/DA (Machine Learning/AData Analysis) de ahi a DevOps y de ahí a producto.
#
# ETL (que significa extraer, transformar, cargar) es un proceso de integración de datos que combina, limpia y organiza los datos de varias fuentes en un conjunto de datos único y coherente para almacenarlos en un almacén de datos, data lake u otro sistema de destino.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. Importa las librerías necesarias

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2. Importa el dataset de este [enlace](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user) y guárdalo en una variable llamada users. Usa pd.read_csv()

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'

users = pd.read_csv(url, sep = "|")

print(users)
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### 3. Muestra las 25 primeros registros

# %%
print(users[:25])
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# 19       20   42      F      homemaker    95660
# 20       21   26      M         writer    30068
# 21       22   25      M         writer    40206
# 22       23   30      F         artist    48197
# 23       24   21      F         artist    94533
# 24       25   39      M       engineer    55107

# %% [markdown]
# ### 4. Muestra las 25 primeros registros de otra forma

# %%
print(users.head(25))
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# 19       20   42      F      homemaker    95660
# 20       21   26      M         writer    30068
# 21       22   25      M         writer    40206
# 22       23   30      F         artist    48197
# 23       24   21      F         artist    94533
# 24       25   39      M       engineer    55107

# %%
users.iloc[:25]
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# 19       20   42      F      homemaker    95660
# 20       21   26      M         writer    30068
# 21       22   25      M         writer    40206
# 22       23   30      F         artist    48197
# 23       24   21      F         artist    94533
# 24       25   39      M       engineer    55107

# %%
# loc muestra el ultimo valor del slicing
users.loc[:24]
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# 19       20   42      F      homemaker    95660
# 20       21   26      M         writer    30068
# 21       22   25      M         writer    40206
# 22       23   30      F         artist    48197
# 23       24   21      F         artist    94533
# 24       25   39      M       engineer    55107

# %% [markdown]
# ### 5. Muestra los últimos 25 registros

# %%
print(users[len(users) - 25 :])
# Out:
#      user_id  age gender     occupation zip_code
# 918      919   25      M          other    14216
# 919      920   30      F         artist    90008
# 920      921   20      F        student    98801
# 921      922   29      F  administrator    21114
# 922      923   21      M        student    E2E3R
# 923      924   29      M          other    11753
# 924      925   18      F       salesman    49036
# 925      926   49      M  entertainment    01701
# 926      927   23      M     programmer    55428
# 927      928   21      M        student    55408
# 928      929   44      M      scientist    53711
# 929      930   28      F      scientist    07310
# 930      931   60      M       educator    33556
# 931      932   58      M       educator    06437
# 932      933   28      M        student    48105
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
print(users[-25 :])
# Out:
#      user_id  age gender     occupation zip_code
# 918      919   25      M          other    14216
# 919      920   30      F         artist    90008
# 920      921   20      F        student    98801
# 921      922   29      F  administrator    21114
# 922      923   21      M        student    E2E3R
# 923      924   29      M          other    11753
# 924      925   18      F       salesman    49036
# 925      926   49      M  entertainment    01701
# 926      927   23      M     programmer    55428
# 927      928   21      M        student    55408
# 928      929   44      M      scientist    53711
# 929      930   28      F      scientist    07310
# 930      931   60      M       educator    33556
# 931      932   58      M       educator    06437
# 932      933   28      M        student    48105
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
# Por defecto, si no se pone nunero en los argumentos, se cogen los 5 ultimos registros
print(users.tail(25))
# Out:
#      user_id  age gender     occupation zip_code
# 918      919   25      M          other    14216
# 919      920   30      F         artist    90008
# 920      921   20      F        student    98801
# 921      922   29      F  administrator    21114
# 922      923   21      M        student    E2E3R
# 923      924   29      M          other    11753
# 924      925   18      F       salesman    49036
# 925      926   49      M  entertainment    01701
# 926      927   23      M     programmer    55428
# 927      928   21      M        student    55408
# 928      929   44      M      scientist    53711
# 929      930   28      F      scientist    07310
# 930      931   60      M       educator    33556
# 931      932   58      M       educator    06437
# 932      933   28      M        student    48105
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
print(users.iloc[-25:])
# Out:
#      user_id  age gender     occupation zip_code
# 918      919   25      M          other    14216
# 919      920   30      F         artist    90008
# 920      921   20      F        student    98801
# 921      922   29      F  administrator    21114
# 922      923   21      M        student    E2E3R
# 923      924   29      M          other    11753
# 924      925   18      F       salesman    49036
# 925      926   49      M  entertainment    01701
# 926      927   23      M     programmer    55428
# 927      928   21      M        student    55408
# 928      929   44      M      scientist    53711
# 929      930   28      F      scientist    07310
# 930      931   60      M       educator    33556
# 931      932   58      M       educator    06437
# 932      933   28      M        student    48105
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %% [markdown]
# ### 6. Cuántos registros hay en total en este dataset?
# Resuélvelo de al menos dos formas diferentes

# %%
print(users.shape)
# Out:
# (943, 5)

# %%
print(users.shape[0])
# Out:
# 943

# %%
print(len(users))
# Out:
# 943

# %%
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %%
users.index.size
# Out:
# 943

# %%
len(users.index)
# Out:
# 943

# %% [markdown]
# ### 7. Cuántas columnas hay en total en este dataset?
# Resuélvelo de al menos dos formas diferentes

# %%
print(users.shape[1])
# Out:
# 5

# %%
# Lista los valores de cada columna, columna 0 en este caso
len(users.values[0])
# Out:
# 5

# %%
# Lista los valores de cada columna, columna 1 en este caso
len(users.values[1])
# Out:
# 5

# %% [markdown]
# ### 8. Haz un print de cada uno de los nombres de las columnas

# %%
print(users.columns)
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
for elem in users.columns:
    print(elem)
# Out:
# user_id
# age
# gender
# occupation
# zip_code

# %% [markdown]
# ### 9. Accede al índice, a los nombres de las columnas y a los valores por separado

# %%
print(users.index)

print("*" * 100)

print(users.columns)

print("*" * 100)

print(users.values)
# Out:
# RangeIndex(start=0, stop=943, step=1)
# ****************************************************************************************************
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')
# ****************************************************************************************************
# [[1 24 'M' 'technician' '85711']
#  [2 53 'F' 'other' '94043']
#  [3 23 'M' 'writer' '32067']
#  ...
#  [941 20 'M' 'student' '97229']
#  [942 48 'F' 'librarian' '78209']
#  [943 22 'M' 'student' '77841']]

# %% [markdown]
# ### 10. Cuál es el tipo de cada columna del dataset?
# Hazlo de dos formas diferentes

# %%
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %% [markdown]
# ### 11. Haz un print solo de la columna de occupation
# Hazlo de dos formas diferentes

# %%
# Pandas trata las columnas como atributos. Aquí la busqueda es a traves de python
print(users.occupation)
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
# Aquí la busqueda se hace a través de pandas
users["occupation"]
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
users.loc[:, "occupation"]
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
# loc permite sacar más de una columna haciendo una especie de sliacing
users.loc[:, "age": "zip_code"]
# Out:
#      age gender     occupation zip_code
# 0     24      M     technician    85711
# 1     53      F          other    94043
# 2     23      M         writer    32067
# 3     24      M     technician    43537
# 4     33      F          other    15213
# ..   ...    ...            ...      ...
# 938   26      F        student    33319
# 939   32      M  administrator    02215
# 940   20      M        student    97229
# 941   48      F      librarian    78209
# 942   22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# A NIVEL DATOS, A NIVEL TABLAS, LAS VARIABLES VAN A SER LAS COLUMNAS

# %% [markdown]
# ### 12. ¿Cuántas profesiones diferentes hay? ¿Y personas por profesión?

# %%
# Profesiones diferentes que hay 
# nunique, enumera los valores unicos
print("Hay", users["occupation"].nunique(), "profesiones diferentes")

print("*" * 100)

# Personas por profesión
print("Número de personas por profesión")
print(users["occupation"].value_counts())
# Saca una serie con la ocupación como índice. Est ya podría pasarse a una grafica
# Out:
# Hay 21 profesiones diferentes
# ****************************************************************************************************
# Número de personas por profesión
# occupation
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: count, dtype: int64

# %%
# Decuelve los valores únicos
print(users["occupation"].unique())
# Out:
# ['technician' 'other' 'writer' 'executive' 'administrator' 'student'
#  'lawyer' 'educator' 'scientist' 'entertainment' 'programmer' 'librarian'
#  'homemaker' 'artist' 'engineer' 'marketing' 'none' 'healthcare' 'retired'
#  'salesman' 'doctor']

# %% [markdown]
# ### Si quiseramos hacer una gráfica, sacaríamos el indice y los valores por separado y se podrían asignar al eje x y al eje y

# %%
print(users["occupation"].value_counts().index)
# Out:
# Index(['student', 'other', 'educator', 'administrator', 'engineer',
#        'programmer', 'librarian', 'writer', 'executive', 'scientist', 'artist',
#        'technician', 'marketing', 'entertainment', 'healthcare', 'retired',
#        'lawyer', 'salesman', 'none', 'homemaker', 'doctor'],
#       dtype='object', name='occupation')

# %%
print(users["occupation"].value_counts().values)
# Out:
# [196 105  95  79  67  66  51  45  32  31  28  27  26  18  16  14  12  12
#    9   7   7]

# %% [markdown]
# ### 13. ¿Cuál es la profesión más común?

# %%
# value.counts saca una serie en la que occuppation es un indice 
print(users["occupation"].value_counts().idxmax())
print(users["occupation"].value_counts().max())
# Out:
# student
# 196

# %%
# Aquí se hace sacando la moda
print(users["occupation"].mode())
# Out:
# 0    student
# Name: occupation, dtype: object

# %%
print(users["occupation"].value_counts().nlargest(1))
# Out:
# occupation
# student    196
# Name: count, dtype: int64

# %%
print(users["occupation"].value_counts().index[0])
# Out:
# student

# %% [markdown]
# ### 14. Obtén un resumen de las principales medidas estadísticas de las variables numéricas.  Usa describe()

# %%
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %% [markdown]
# PERCENTILES

# %% [markdown]
# ### 15. Obtén un resumen de las principales medidas estadísticas de todas las variables.  Usa describe()

# %%
users.describe(include="all")
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %% [markdown]
# ### 16. Obtén un resumen de las principales medidas estadísticas de solo la columna occupation.  Usa describe()

# %%
users["occupation"].describe()
# Out:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %% [markdown]
# ### 17. ¿Cuál es la edad media?

# %%
print("La edad media es: ", round(users["age"].mean(), 2))
# Out:
# La edad media es:  34.05

# %% [markdown]
# ### 18. ¿Cuál es la edad menos frecuente?

# %%
print("Edad menos fecuente es: ", users["age"].value_counts().idxmin())
print("Número de personas con 7 años: ", users["age"].value_counts().min())


edades = users["age"].value_counts()

print("*" * 100)

print("Edades menos frecuentes:\n")
print(edades[edades == edades.min()])
# Out:
# Edad menos fecuente es:  7
# Número de personas con 7 años:  1
# ****************************************************************************************************
# Edades menos frecuentes:
#
# age
# 7     1
# 11    1
# 66    1
# 10    1
# 73    1
# Name: count, dtype: int64

# %%
lista = users["age"].value_counts()
lista[lista == lista.min()]
# Out:
# age
# 7     1
# 11    1
# 66    1
# 10    1
# 73    1
# Name: count, dtype: int64

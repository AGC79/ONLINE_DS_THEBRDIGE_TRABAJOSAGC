# %% [markdown]
# # EXTRACCIÓN DE DATOS

# %% [markdown]
# Normalmente la extracción de datos en empresas se realiza mediante consultas a bases de datos relacionales con SQL.
#
# Un analista de datos tiene que ser capaz de automaizar las extracción de esos datos y convertirlos en un dataset en formato csv.
#
# Normalmente, un analista extrae esos datos por medio de una API a través de un endpoint.

# %% [markdown]
# # 🔹 Qué es un Endpoint en el contexto de APIs
#
# ## 1️⃣ API (Application Programming Interface)
# - Es un **puente entre sistemas** que permite que un programa “hable” con otro.
# - Ejemplo: una API de datos deportivos permite pedir información sobre partidos, jugadores o estadísticas.
#
# ## 2️⃣ Endpoint
# - Es una **URL específica dentro de la API** que permite acceder a un recurso concreto.
# - Analogía:
#   - La API es un **restaurante completo**.
#   - El endpoint es un **plato específico del menú** que puedes pedir.

# %% [markdown]
# Métodos más comunes:
#  - APIs
#  - Web Scraping.
#  - BB.DD
#
#  Para esto ya vamos a trabajar más con scripts, no con archivos Jupyter.
#
#  Es importante saber qué tipos archivos hay. En los scripts se han de navegar por directorios.

# %% [markdown]
# # 🔹 Extracción de datos
#
# ## 1️⃣ API
# - Una **API** es un **punto de acceso a datos** de un sistema o servicio.
# - Permite que un analista o aplicación **obtenga información de manera estructurada** (por ejemplo, JSON o CSV) sin necesidad de procesar la página web manualmente.
# - Ejemplo: obtener los resultados de un equipo de fútbol a través de un endpoint de la API.
#
# ## 2️⃣ Web Scraping
# - El **Web Scraping** se utiliza cuando **no hay API disponible**.
# - Consiste en **extraer datos directamente del HTML de una página web** mediante automatizaciones (scripts).
# - Permite capturar información como tablas, listas, precios, noticias, etc., y convertirla en un formato utilizable (DataFrame, CSV, etc.).

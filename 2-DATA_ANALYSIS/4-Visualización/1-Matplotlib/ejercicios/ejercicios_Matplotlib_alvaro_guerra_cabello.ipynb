# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('classic')

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.
#
#
# ## Ecuaciones de la recta
#
# Una recta en el plano puede escribirse de dos formas principales:
#
# ---
#
# ### 1) Forma Punto–Pendiente
#
# \[
# y - y_1 = m(x - x_1)
# \]
#
# Se utiliza cuando conocemos:
# - La **pendiente**: \(m\)
# - Un **punto por donde pasa la recta**: \((x_1, y_1)\)
#
# | Símbolo | Significado |
# |--------|-------------|
# | \(m\) | Pendiente (inclinación de la recta) |
# | \((x_1, y_1)\) | Punto conocido sobre la recta |
#
# ---
#
# ### 2) Forma Pendiente–Intersección
#
# \[
# y = mx + b
# \]
#
# Se utiliza cuando conocemos:
# - La **pendiente**: \(m\)
# - El **corte con el eje Y** (ordenada de origen): \(b\)
#
# | Símbolo | Significado |
# |--------|-------------|
# | \(m\) | Pendiente |
# | \(b\) | Valor de \(y\) cuando \(x = 0\) (punto de corte con el eje Y) |
#
# El punto \((0, b)\) es donde la recta toca el **eje Y**.
#
# ---
#
# ### Relación entre ambas formas
#
# La forma punto–pendiente puede convertirse en la forma pendiente–intersección simplemente despejando \(y\):
#
# $$
# y - y_1 = m(x - x_1) \;\Rightarrow\; y = mx + b
# $$
#
# Es decir, **son la misma recta**, solo escrita de forma diferente.
#
# ---
#
# ### Interpretación visual
#
# - Si \(m > 0\): la recta **sube** hacia la derecha.
# - Si \(m < 0\): la recta **baja** hacia la derecha.
# - \(b\) indica dónde la recta toca el eje Y.

# %%
x = np.linspace(0, 5, 100) # 100 es la precisión en el eje x 

plt.figure()

plt.subplot(1, 2, 1)
plt.plot(x, x * 3, linestyle='-', color='blue');

plt.subplot(1, 2, 2) 
plt.plot(x, (x * (-3)) - 5, linestyle='--', color='red');

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
plt.figure()

plt.subplot(1, 2, 1)
plt.plot(x, x * 3, linestyle='-', color='blue');
plt.xlim(0, 5)
plt.ylim(-15, 15)

plt.subplot(1, 2, 2) 
plt.plot(x, (x * (-3)) -5, linestyle='--', color='red');
plt.xlim(0, 5)
plt.ylim(-15, 15);

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
plt.figure()

plt.subplot(1, 2, 1)
plt.plot(x, x * 3, linestyle='-', color='blue');
plt.xlim(0, 5)
plt.ylim(-15, 15)
plt.title("recta sube")
plt.xlabel("eje X")
plt.ylabel("eje Y")

plt.subplot(1, 2, 2) 
plt.plot(x, (x * (-3)) -5, linestyle='--', color='red');
plt.xlim(0, 5)
plt.ylim(-15, 15)
plt.title("recta baja")
plt.xlabel("eje X")
plt.ylabel("eje Y");

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0, 5, 100)
fig, ax = plt.subplots(1, 2)
ax[0].plot(x, x * 3, linestyle='-', color='blue')
ax[1].plot(x, x * (-3) - 5, linestyle='-.', color='red');

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
plt.figure()

# Las listas mejor que los diccionarios
lista_x = np.arange(20, 29, 2)
lista_y = [5, 15, -5, 20, 5]

plt.bar(lista_x, lista_y)
plt.show()

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
plt.figure()

# Mejor listas que diccionarios, entran mejor
lista_x = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
lista_y = [160, 180, 175, 190, 170]

plt.bar(lista_x, lista_y, color="g")
plt.title("Altura amigos")
plt.xlabel("Nombres de amigos")
plt.ylabel("Altura en cm")
plt.show()

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
plt.figure(figsize=(3,5))

lista_x = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
lista_y = [160, 180, 175, 190, 170]

plt.bar(lista_x, lista_y, color="g")
plt.title("Altura amigos")
plt.xlabel("Nombres de amigos")
plt.ylabel("Altura en cm")
plt.show()

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
plt.figure(figsize=(3, 5))

lista_x = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
lista_y = [160, 180, 175, 190, 170]

plt.bar(lista_x, lista_y, color="g")
plt.title("Altura amigos")
plt.xlabel("Nombres de amigos")
plt.ylabel("Altura en cm")

# Permite meter los valores de las escalas en forma de lis
plt.yticks([])

plt.show()

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
plt.figure(figsize=(3,5))

lista_x = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
lista_y = [160, 180, 175, 190, 170]

plt.barh(lista_x, lista_y, color="g")
plt.title("Altura amigos")
plt.xlabel("Altura en cm")
plt.ylabel("Nombres de amigos")
plt.show()

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles  fuera de la figura

# %%
fig, ax = plt.subplots(1, 1)

lista_x = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
lista_y = [160, 180, 175, 190, 170]

ax.barh(lista_x, lista_y, color="g")
ax.set_title("Altura amigos")
ax.set_xlabel("Altura en cm")
ax.set_ylabel("Nombres de amigos")

ax.invert_xaxis()
plt.show()

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
plt.style.use('dark_background')

fig, ax = plt.subplots(1, 1)

lista_x = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
lista_y = [160, 180, 175, 190, 170]

ax.barh(lista_x, lista_y, color="g")
ax.set_title("Altura amigos")
ax.set_xlabel("Altura en cm")
ax.set_ylabel("Nombres de amigos")

ax.invert_xaxis()
plt.show()

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
dict = [{"Year": [2015, 2016, 2017, 2018, 2019], "Sold_items_A": [1000, 3500, 4000, 5500, 7000]}]
dict[0]["Year"][0]
dict[0]["Sold_items_A"][0]

df_ventas = pd.DataFrame(dict[0])
df_ventas
# Out:
#    Year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-white')
plt.figure()

# plt.subplot(1, 2, 1)
plt.plot(df_ventas["Year"].astype(str), df_ventas["Sold_items_A"], linestyle='--', color='g');
plt.title("Ventas últimos 5 años")
plt.xlabel("Años")
plt.ylabel("Ventas")
# Out:
# Text(0, 0.5, 'Ventas')

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
df_ventas["Sold_items_B"] = [2000, 3100, 5000, 4000, 6000]
df_ventas
# Out:
#    Year  Sold_items_A  Sold_items_B
# 0  2015          1000          2000
# 1  2016          3500          3100
# 2  2017          4000          5000
# 3  2018          5500          4000
# 4  2019          7000          6000

# %%
plt.style.use('seaborn-v0_8-white')
plt.figure()

plt.title("Ventas últimos 5 años")
plt.xlabel("Años")
plt.ylabel("Ventas")
plt.plot(df_ventas["Year"].astype(str), df_ventas["Sold_items_A"], linestyle='-', color='g', label = 'Dep A')
plt.plot(df_ventas["Year"].astype(str), df_ventas["Sold_items_B"], linestyle='--', color='r', label = 'Dep B')

plt.legend(loc="lower right");

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
plt.style.use('seaborn-v0_8-white')

df_ventas.plot(
    x="Year",
    y="Sold_items_A",
    kind="scatter",
    label="Dep A",
    title="Ventas últimos 5 años"
)

plt.xlabel("Años")
plt.ylabel("Ventas")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
plt.style.use('seaborn-v0_8-white')

df_ventas.plot(
    x="Year",
    y="Sold_items_A",
    kind="pie",
    label="Dep A",
    title="Ventas últimos 5 años"
)

plt.xlabel("Años")
plt.ylabel("Ventas")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
plt.style.use('seaborn-v0_8-white')

df_ventas.set_index("Year")["Sold_items_A"].plot(
    kind="pie",
    autopct="%1.1f%%",
    legend=False,           
    title="Ventas últimos 5 años",
    ylabel=""             
)

plt.show()

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %%
plt.style.use('seaborn-v0_8')

data = np.random.randint(150, 191, 300)

plt.hist(data,
         bins = 30,
         alpha = 0.5,
         color = 'steelblue')

plt.show();

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

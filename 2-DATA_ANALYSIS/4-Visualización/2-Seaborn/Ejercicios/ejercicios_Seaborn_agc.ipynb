# %% [markdown]
# # Ejercicios de Seaborn

# %%
# 1. Importa pandas, pyplot y seaborn

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame
df_pokemon = pd.read_csv(".\\data\\Pokemon.csv")
df_pokemon = df_pokemon.set_index("#")

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados
df_pokemon.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del función en el parámetro llamado data
# A aparte de la dispersión, se ve también  la linea de regresión.
# El sombreado de esa línea ayuda a visualizar y evaluar la dispersión 
sns.lmplot(df_pokemon, x="Attack", y="Defense", hue="Stage");

# %%
# Aquí se muestra la evolucion de cada pokemon
df_pokemon["Stage"].value_counts()
# Out:
# Stage
# 1    79
# 2    56
# 3    16
# Name: count, dtype: int64

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso
sns.lmplot(df_pokemon, x="Attack", y="Defense", fit_reg=False, hue= "Stage");

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage
sns.lmplot(df_pokemon, x="Attack", y="Speed", fit_reg=False, hue="Stage");

# %%
# 8. Limita el eje x entre 20 y 100
sns.lmplot(df_pokemon, x="Attack", y="Defense", fit_reg=False, hue="Stage");
plt.xlim(20, 100);

# %%
# 9. Dibuja un diagrama de cajas con el dataframe
plt.figure(figsize=(20,15))
sns.boxplot(data=df_pokemon.select_dtypes(include="number"), color="sienna");

# %%
sns.boxplot(data=df_pokemon, x = "Defense", color="sienna");

# %%
sns.boxplot(data=df_pokemon, color="sienna");

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas
df_pokemon_parcial = df_pokemon.drop(["Total", "Stage", "Legendary"], axis=1)
df_pokemon_parcial.head()
# Out:
#          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2     Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3    Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Charmander   Fire     NaN  39      52       43       60       50     65
# 5  Charmeleon   Fire     NaN  58      64       58       80       65     80

# %%
# Otra opción alternativa a la anterior
df_pokemon.drop(columns=["Total", "Stage", "Legendary"])

# %%
plt.figure(figsize=(20,15))
sns.boxplot(data=df_pokemon.select_dtypes(include="number"));

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame
df_pokemon["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon'], dtype=object)

# %%
print("Número de 'Type 1' diferentes:", df_pokemon["Type 1"].nunique())
# Out:
# Número de 'Type 1' diferentes: 15

# %%
len(df_pokemon["Type 1"].unique())
# Out:
# 15

# %%
df_pokemon["Type 1"].value_counts()
# Out:
# Type 1
# Water       28
# Normal      22
# Poison      14
# Fire        12
# Grass       12
# Bug         12
# Electric     9
# Rock         9
# Ground       8
# Psychic      8
# Fighting     7
# Dragon       3
# Ghost        3
# Fairy        2
# Ice          2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(
    df_pokemon["Type 1"].value_counts(),
    labels=df_pokemon["Type 1"].value_counts().index,
    autopct="%1.1f%%"
)
plt.show()

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'
#df_pokemon = df_pokemon[(df_pokemon["Type 1"] == "Grass") | (df_pokemon["Type 1"] == "Fire") | (df_pokemon["Type 1"] == "Water")]["Type 1"] 
df_pokemon
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %%
df_pokemon_02 = df_pokemon[df_pokemon["Type 1"].isin(['Grass', "Fire", "Water"])]
df_pokemon_02
# Out:
#            Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur  Grass    Poison    318   45      49       49       65
# 2       Ivysaur  Grass    Poison    405   60      62       63       80
# 3      Venusaur  Grass    Poison    525   80      82       83      100
# 4    Charmander   Fire       NaN    309   39      52       43       60
# 5    Charmeleon   Fire       NaN    405   58      64       58       80
# 6     Charizard   Fire    Flying    534   78      84       78      109
# 7      Squirtle  Water       NaN    314   44      48       65       50
# 8     Wartortle  Water       NaN    405   59      63       80       65
# 9     Blastoise  Water       NaN    530   79      83      100       85
# 37       Vulpix   Fire       NaN    299   38      41       40       50
# 38    Ninetales   Fire       NaN    505   73      76       75       81
# 43       Oddish  Grass    Poison    320   45      50       55       75
# 44        Gloom  Grass    Poison    395   60      65       70       85
# 45    Vileplume  Grass    Poison    490   75      80       85      110
# 54      Psyduck  Water       NaN    320   50      52       48       65
# 55      Golduck  Water       NaN    500   80      82       78       95
# 58    Growlithe   Fire       NaN    350   55      70       45       70
# 59     Arcanine   Fire       NaN    555   90     110       80      100
# 60      Poliwag  Water       NaN    300   40      50       40       40
# 61    Poliwhirl  Water       NaN    385   65      65       65       50
# 62    Poliwrath  Water  Fighting    510   90      95       95       70
# 69   Bellsprout  Grass    Poison    300   50      75       35       70
# 70   Weepinbell  Grass    Poison    390   65      90       50       85
# 71   Victreebel  Grass    Poison    490   80     105       65      100
# 72    Tentacool  Water    Poison    335   40      40       35       50
# 73   Tentacruel  Water    Poison    515   80      70       65       80
# 77       Ponyta   Fire       NaN    410   50      85       55       65
# 78     Rapidash   Fire       NaN    500   65     100       70       80
# 79     Slowpoke  Water   Psychic    315   90      65       65       40
# 80      Slowbro  Water   Psychic    490   95      75      110      100
# 86         Seel  Water       NaN    325   65      45       55       45
# 87      Dewgong  Water       Ice    475   90      70       80       70
# 90     Shellder  Water       NaN    305   30      65      100       45
# 91     Cloyster  Water       Ice    525   50      95      180       85
# 98       Krabby  Water       NaN    325   30     105       90       25
# 99      Kingler  Water       NaN    475   55     130      115       50
# 102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 114     Tangela  Grass       NaN    435   65      55      115      100
# 116      Horsea  Water       NaN    295   30      40       70       70
# 117      Seadra  Water       NaN    440   55      65       95       95
# 118     Goldeen  Water       NaN    320   45      67       60       35
# 119     Seaking  Water       NaN    450   80      92       65       65
# 120      Staryu  Water       NaN    340   30      45       55       70
# 121     Starmie  Water   Psychic    520   60      75       85      100
# 126      Magmar   Fire       NaN    495   65      95       57      100
# 129    Magikarp  Water       NaN    200   20      10       55       15
# 130    Gyarados  Water    Flying    540   95     125       79       60
# 131      Lapras  Water       Ice    535  130      85       80       85
# 134    Vaporeon  Water       NaN    525  130      65       60      110
# 136     Flareon   Fire       NaN    525   65     130       60       95
# 146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# 6         85    100      3      False
# 7         64     43      1      False
# 8         80     58      2      False
# 9        105     78      3      False
# 37        65     65      1      False
# 38       100    100      2      False
# 43        65     30      1      False
# 44        75     40      2      False
# 45        90     50      3      False
# 54        50     55      1      False
# 55        80     85      2      False
# 58        50     60      1      False
# 59        80     95      2      False
# 60        40     90      1      False
# 61        50     90      2      False
# 62        90     70      3      False
# 69        30     40      1      False
# 70        45     55      2      False
# 71        70     70      3      False
# 72       100     70      1      False
# 73       120    100      2      False
# 77        65     90      1      False
# 78        80    105      2      False
# 79        40     15      1      False
# 80        80     30      2      False
# 86        70     45      1      False
# 87        95     70      2      False
# 90        25     40      1      False
# 91        45     70      2      False
# 98        25     50      1      False
# 99        50     75      2      False
# 102       45     40      1      False
# 103       65     55      2      False
# 114       40     60      1      False
# 116       25     60      1      False
# 117       45     85      2      False
# 118       50     63      1      False
# 119       80     68      2      False
# 120       55     85      1      False
# 121       85    115      2      False
# 126       85     93      1      False
# 129       20     80      1      False
# 130      100     81      2      False
# 131       95     60      1      False
# 134       95     65      2      False
# 136      110     65      2      False
# 146       85     90      1       True

# %%
# 13. Usa un estilo 'whitegrid'
sns.set_style("whitegrid")

# %%
# 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos
plt.figure(figsize=(10, 5))
sns.violinplot(data=df_pokemon_02, x="Type 1", y="Attack")
# Out:
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'
colores= ['#78C850', '#F08030', '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)
plt.figure(figsize=(10, 5))
sns.violinplot(data=df_pokemon_02, x="Type 1", y="Attack", palette=colores)
# Out:
# C:\Users\Administrador\AppData\Local\Temp\ipykernel_8288\137214248.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_pokemon_02, x="Type 1", y="Attack", palette=colores)
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violi
plt.figure(figsize=(10, 5))
"""
sns.violinplot(data=df_pokemon_parcial_02, 
               x="Type 1", y="Attack", 
               palette=colores)
"""

sns.swarmplot(data=df_pokemon_02,
              x="Type 1", y="Attack", 
              palette=colores);
# Out:
# C:\Users\Administrador\AppData\Local\Temp\ipykernel_8288\639038376.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=df_pokemon_02,

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# Pon un título con pyplot (como siempre)

# plt.figure(figsize=(10, 5))

sns.violinplot(data=df_pokemon_02, 
               x="Type 1", y="Attack", 
               palette=colores,
               inner = None,
               alpha = 0.9)

sns.swarmplot(data=df_pokemon_02,
              x="Type 1", y="Attack", 
              color="black",  alpha=0.9);
# Out:
# C:\Users\Administrador\AppData\Local\Temp\ipykernel_8288\3784684723.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_pokemon_02,

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

df_pokemon_02.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

df_gfw = df_pokemon_02.melt(id_vars=['Name', 'Type 1'],
                            value_vars=df_pokemon_02.columns[3:11],
                            var_name='New Column')
df_gfw
# Out:
#            Name Type 1 New Column  value
# 0     Bulbasaur  Grass      Total    318
# 1       Ivysaur  Grass      Total    405
# 2      Venusaur  Grass      Total    525
# 3    Charmander   Fire      Total    309
# 4    Charmeleon   Fire      Total    405
# ..          ...    ...        ...    ...
# 411    Gyarados  Water      Stage      2
# 412      Lapras  Water      Stage      1
# 413    Vaporeon  Water      Stage      2
# 414     Flareon   Fire      Stage      2
# 415     Moltres   Fire      Stage      1
#
# [416 rows x 4 columns]

# %%
df_gfw["Name"] == "Bulbasaur"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 411    False
# 412    False
# 413    False
# 414    False
# 415    False
# Name: Name, Length: 416, dtype: bool

# %%
df_gfw_02 = df_gfw[df_gfw["Name"] == "Bulbasaur"]

# %%
pd.pivot(df_gfw, columns="New Column", values="value", index = "Name")
# Out:
# New Column  Attack  Defense   HP  Sp. Atk  Sp. Def  Speed  Stage  Total
# Name
# Arcanine       110       80   90      100       80     95      2    555
# Bellsprout      75       35   50       70       30     40      1    300
# Blastoise       83      100   79       85      105     78      3    530
# Bulbasaur       49       49   45       65       65     45      1    318
# Charizard       84       78   78      109       85    100      3    534
# Charmander      52       43   39       60       50     65      1    309
# Charmeleon      64       58   58       80       65     80      2    405
# Cloyster        95      180   50       85       45     70      2    525
# Dewgong         70       80   90       70       95     70      2    475
# Exeggcute       40       80   60       60       45     40      1    325
# Exeggutor       95       85   95      125       65     55      2    520
# Flareon        130       60   65       95      110     65      2    525
# Gloom           65       70   60       85       75     40      2    395
# Goldeen         67       60   45       35       50     63      1    320
# Golduck         82       78   80       95       80     85      2    500
# Growlithe       70       45   55       70       50     60      1    350
# Gyarados       125       79   95       60      100     81      2    540
# Horsea          40       70   30       70       25     60      1    295
# Ivysaur         62       63   60       80       80     60      2    405
# Kingler        130      115   55       50       50     75      2    475
# Krabby         105       90   30       25       25     50      1    325
# Lapras          85       80  130       85       95     60      1    535
# Magikarp        10       55   20       15       20     80      1    200
# Magmar          95       57   65      100       85     93      1    495
# Moltres        100       90   90      125       85     90      1    580
# Ninetales       76       75   73       81      100    100      2    505
# Oddish          50       55   45       75       65     30      1    320
# Poliwag         50       40   40       40       40     90      1    300
# Poliwhirl       65       65   65       50       50     90      2    385
# Poliwrath       95       95   90       70       90     70      3    510
# Ponyta          85       55   50       65       65     90      1    410
# Psyduck         52       48   50       65       50     55      1    320
# Rapidash       100       70   65       80       80    105      2    500
# Seadra          65       95   55       95       45     85      2    440
# Seaking         92       65   80       65       80     68      2    450
# Seel            45       55   65       45       70     45      1    325
# Shellder        65      100   30       45       25     40      1    305
# Slowbro         75      110   95      100       80     30      2    490
# Slowpoke        65       65   90       40       40     15      1    315
# Squirtle        48       65   44       50       64     43      1    314
# Starmie         75       85   60      100       85    115      2    520
# Staryu          45       55   30       70       55     85      1    340
# Tangela         55      115   65      100       40     60      1    435
# Tentacool       40       35   40       50      100     70      1    335
# Tentacruel      70       65   80       80      120    100      2    515
# Vaporeon        65       60  130      110       95     65      2    525
# Venusaur        82       83   80      100      100     80      3    525
# Victreebel     105       65   80      100       70     70      3    490
# Vileplume       80       85   75      110       90     50      3    490
# Vulpix          41       40   38       50       65     65      1    299
# Wartortle       63       80   59       65       80     58      2    405
# Weepinbell      90       50   65       85       45     55      2    390

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información

colores_02 = ["#FF6B6B", "#FFD93D", "#6BCB77"]

plt.figure(figsize=(12,6))

sns.swarmplot(
    data=df_gfw,
    x="Type 1",
    y="value",
    hue="Type 1",       
    palette=colores_02,
    size=7)

plt.legend(loc='upper left')

plt.show()
# Out:
# C:\Users\Administrador\AppData\Local\Temp\ipykernel_8288\3459412276.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='upper left')
# c:\Users\Administrador\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

colores_02 = ["#FF6B6B", "#FFD93D", "#6BCB77"]

plt.figure(figsize=(10, 6))

sns.swarmplot(
    data=df_gfw,
    x="Type 1",
    y="value",
    hue="New Column",
    dodge=True,       
    palette=colores,
    size=7)

plt.legend(loc='upper left')

plt.show()

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)
df_pokemon_reoladed = pd.read_csv(".\\data\\Pokemon.csv")
df_pokemon_reoladed = df_pokemon_reoladed.set_index("#")
df_pokemon_reoladed
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %%
df_pokemon_reoladed.select_dtypes(include='number').corr()
# Out:
#             Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed  \
# Total    1.000000  0.576591  0.670939  0.508694  0.680745  0.774383  0.506950
# HP       0.576591  1.000000  0.306768  0.119782  0.236649  0.490978 -0.040939
# Attack   0.670939  0.306768  1.000000  0.491965  0.146312  0.369069  0.194701
# Defense  0.508694  0.119782  0.491965  1.000000  0.187569  0.139912 -0.053252
# Sp. Atk  0.680745  0.236649  0.146312  0.187569  1.000000  0.522907  0.411516
# Sp. Def  0.774383  0.490978  0.369069  0.139912  0.522907  1.000000  0.392656
# Speed    0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656  1.000000
# Stage    0.504224  0.249207  0.361321  0.270861  0.391712  0.358308  0.240042
#
#             Stage
# Total    0.504224
# HP       0.249207
# Attack   0.361321
# Defense  0.270861
# Sp. Atk  0.391712
# Sp. Def  0.358308
# Speed    0.240042
# Stage    1.000000

# %%
sns.heatmap(df_pokemon_reoladed.corr(numeric_only=True), annot=True, cmap="seismic", vmin=-1);

# %% [markdown]
# Ejemplo*: variable metros cuadrados y con precio piso tienen correlación positica e interesa. Pero la variable m2 tb puede tener correlación positiva con la variable hectáreas, pero esta correlación no tiene por que interesar.

# %%
# ¿la correlación entre qué valores se encuentra? 
# La correlación se encuentra **entre 1 y 0.14**.  
"""
     - Valores cercanos a 1 → correlación positiva fuerte una varible sube, la otra tambien.  
     - Valores cercanos a -1 → correlación negativa fuerte, una variable sube, la otra baja.  
     - Valores cercanos a 0 → casi ninguna correlación lineal, las varioables no se afectan mutuamente.
"""
# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias? 
#  Todas las variables tienen **autocorrelación = 1**, lo cual es normal porque una variable siempre está perfectamente correlacionada consigo misma.
# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# `Sp. Def` y `Total` tienen una correlación de **0.774**, lo que indica que Pokémon con mayor defensa especial suelen tener un total de estadísticas más alto.
# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías? (ML) 
# Quitar correlaciones que no interesan, las bajas. una correlación se considera a partir de 0.6 
# Elegir variables más importantes.    
# Mirar las correlaciones que sean fuertemente postivas o fuertemente negativas.

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

plt.figure(figsize=(10,5))
sns.histplot(df_pokemon_reoladed["Defense"], kde = True);

# %%
df_pokemon_reoladed
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

plt.figure(figsize=(10,5))

sns.countplot(data=df_pokemon_reoladed, x="Type 1", palette="Set2")

plt.xticks(rotation = 45);
# Out:
# C:\Users\Administrador\AppData\Local\Temp\ipykernel_8288\2349466908.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_pokemon_reoladed, x="Type 1", palette="Set2")

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

plt.figure(figsize=(10,5))

sns.countplot(df_pokemon_reoladed["Type 1"])
# Out:
# <Axes: xlabel='count', ylabel='Type 1'>

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

plt.figure(figsize=(10,5))

grafico = sns.catplot(data=df_pokemon_reoladed,
            x="Type 1",
            y="Defense",
            hue="Type 2",       
            col="Legendary");

grafico.set_xticklabels(rotation = 45)

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).

plt.figure(figsize=(10,6))

sns.kdeplot(
    data=df_pokemon_reoladed,
    x="Attack",
    y="Defense",
)

plt.title("Distribución de Attack vs Defense por Type 1")
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.show()

# %%
# 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

sns.jointplot(x=df_pokemon_reoladed['Defense'],
              y=df_pokemon_reoladed['Attack'],
              kind="kde",      
              fill=True,        
              cmap="crest", 
              height = 8);

# %%
sns.jointplot(data=df_pokemon_reoladed, 
              x='Attack',
              y='Defense');

# %%
# 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

sns.jointplot(data = df_pokemon_reoladed,
              x='Attack',
              y='Defense',
              kind="kde");

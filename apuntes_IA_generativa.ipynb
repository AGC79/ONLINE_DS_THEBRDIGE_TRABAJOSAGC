# %% [markdown]
# # 🧠 INTELIGENCIA ARTIFICIAL
#
# **ChatGPT** es un ejemplo de **asistente basado en Inteligencia Artificial (IA)**.
#
# ---
#
# ## 🔹 Almacenamiento de respuestas
# - Las respuestas de un asistente de IA **no se almacenan automáticamente** en una base de datos.
# - Se generan en **tiempo real** y **no se guardan**, salvo que el sistema esté configurado para ello (por ejemplo, para mejorar el modelo o registrar conversaciones).
#
# ---
#
# ## 🔹 IA Generativa
# - Una **IA generativa** (como ChatGPT o DALL·E):
#   - **Recoge datos de entrada** (texto, imagen, audio…)
#   - **Genera nuevos datos** (respuestas, imágenes, sonidos…)
# - Los datos generados **no tienen por qué almacenarse**.
#   - Ejemplo: los resultados de un cálculo estadístico pueden visualizarse sin guardarse en una base de datos.
#
# ---
#
# # ⚙️ Proceso general de funcionamiento
#
# ## 🟩 PASO 1: El *prompt*
# - Toda IA necesita un **prompt** (entrada o instrucción).
# - El prompt puede ser:
#   - Una **pregunta**:
#     > “¿Qué es el aprendizaje automático?”
#   - Una **lista de datos**, o incluso **imagen** o **audio**.
#
# ---
#
# ## 🟩 PASO 2: Interpretación del prompt
# - El sistema interpreta el prompt y lo **convierte en una representación numérica** (vectores).
# - Todo tipo de dato (texto, imagen, audio) se traduce a **números**.
# - Para el texto, se usa **Procesamiento de Lenguaje Natural (NLP)**:
#   - Relaciona palabras con su contexto y significado.
# - Resultado: una **lista de números** que representa el contenido del prompt.
#
# ---
#
# ## 🟩 PASO 3: Procesamiento (el modelo)
# - El modelo de IA toma la **lista de números de entrada**.
# - Mediante cálculos y redes neuronales, **genera otra lista de números**: la representación interna de la respuesta.
#
# ---
#
# ## 🟩 PASO 4: Generación de la salida
# - El decodificador toma la **lista de números generada** y la convierte en:
#   - Texto
#   - Imagen
#   - Sonido
#   - Acción
# - Todo depende del tipo de IA.
#
# ---
#
# ## 🔁 Resumen de los pasos
#
# | Paso | Qué hace | Ejemplo |
# |------|----------|---------|
# | 1 | Recibir un prompt | “Explica qué es el aprendizaje automático” |
# | 2 | Convertirlo a números | `[0.45, 0.88, -0.12, …]` |
# | 3 | Procesamiento interno | Calcula patrones y relaciones |
# | 4 | Generación de salida | Texto: “El aprendizaje automático es una rama de la IA...” |
#
# ---
#
# > 💡 Nota: Todo el proceso de la IA es **numérico** en su interior; el texto, imágenes o audio son solo **representaciones finales** para el usuario.
